# %% [markdown]
# # Kaggle Dataset Analysis (Placeholder)
#
# Use this notebook to explore external datasets after download and parsing.
# No raw datasets are stored in the repo.

# %%
from pathlib import Path
import json

processed_dir = Path("../data/processed")
pairs_path = processed_dir / "pairs.jsonl"
if pairs_path.exists():
    with pairs_path.open("r", encoding="utf-8") as handle:
        rows = [json.loads(line) for line in handle if line.strip()]
    print("pairs", len(rows))
else:
    print("No processed pairs found.")
